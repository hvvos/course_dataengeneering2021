# %%
"""
Lists
"""

primes = [2, 3, 5, 7, 11, 2]
print(primes)

empty_list = []
print(empty_list)
# Out:
# [2, 3, 5, 7, 11, 2]
# []

# %%
"""
Multiple different data types
"""

mixed = ['Jenny', 1, 1.4, True]
print(mixed)
list_of_lists = [['a', 1], ['b',2]]
print(list_of_lists)
# Out:
# ['Jenny', 1, 1.4, True]
# [['a', 1], ['b', 2]]

# %%
"""
Zero-indexing
"""

names = ['Roger', 'Rafael', 'Andy', 'Novak']

print(names[0])
print(names[3])
# Out:
# Roger
# Novak

# %%
"""
Negative indexing
"""

print(names[-1]) #Last data
print(names[-4]) #fourth to last data
# Out:
# Novak
# Roger

# %%
"""
List slicing
"""

hsu_buildings = ['만우관', '장공관', '필헌관', '소통관', '송암관', '늦봄관', '장준하통일관']
building_slice = hsu_buildings[2:5]
print(building_slice)
#맨 마지막껀 포함 X
building_slice2 = hsu_buildings[:4]
print(building_slice2)
#맨 마지막꺼 포함
building_slice[0] = '생활관'
print(building_slice)
# Out:
# ['필헌관', '소통관', '송암관']
# ['만우관', '장공관', '필헌관', '소통관']
# ['생활관', '소통관', '송암관']

# %%
"""
Multi-dimensional Lists
"""

restaurants = [['해우리', '한식', '고S'], ['짜장명가', '중식', '중화비빔밥'], ['찌개동아리', '한식', '제육전골'], ['맘스터치', '양식', '싸이버거']]

print(restaurants)
print(restaurants[1][2])

restaurants[0][2] = '해우라면'
print(restaurants[0])
# Out:
# [['해우리', '한식', '고S'], ['짜장명가', '중식', '중화비빔밥'], ['찌개동아리', '한식', '제육전골'], ['맘스터치', '양식', '싸이버거']]
# 중화비빔밥
# ['해우리', '한식', '해우라면']

# %%
"""
Adding Lists Together
"""

items_one = ['cake', 'cookie', 'bread']
items_two = ['biscuit', 'tart']

total_items = items_one + items_two
print(total_items)
# Out:
# ['cake', 'cookie', 'bread', 'biscuit', 'tart']

# %%
"""
Useful Methods for Lists
"""

#len() = lenghth
knapsack = [2, 4, 3, 7 ,10, 2]
size = len(knapsack)
print(size)

#count - 갯수 세기
num = knapsack.count(2)
print(num)

#append() - 맨 마지막에 추가
orders = ['daisies', 'periwinkle']
orders.append('tulips')
print(orders)

#insert() - 특정 위치에 추가
orders.insert(1, 'insert')
print(orders)

#pop() - 특정 위치에 있는 것 삭제
orders.pop(1)
print(orders)

#remove() - 특정 아이템 제거
orders.remove('tulips')
print(orders)
"""
orders.remove('nothing')
print(orders)
"""

#sort() - 리스트 내 아이템 정렬
numbers = ['1', '3', '4', '2']
list.sort(numbers)
print(numbers)

#sorted() - 정렬된 리스트를 리턴
sorted_numbers = sorted(numbers)
print(sorted_numbers)
# Out:
# 6
# 2
# ['daisies', 'periwinkle', 'tulips']
# ['daisies', 'insert', 'periwinkle', 'tulips']
# ['daisies', 'periwinkle', 'tulips']
# ['daisies', 'periwinkle']
# ['1', '2', '3', '4']
# ['1', '2', '3', '4']
