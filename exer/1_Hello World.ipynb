# %%
"""
print() function
"""

print("Hello World")
print(100)
pi = 3.14
print(pi)

intro = "My name is "
name = "Hyeon Woo"
print(intro + name + "!")
# Out:
# Hello World
# 100
# 3.14
# My name is Hyeon Woo!

# %%
"""
Variables
"""
#나를 표현할 수 있는 정보 세가지를 변수로 선언하시오
user_name = "Hyeon Woo"
user_phone = "01026452104"
user_email = "phw5017@naver.com"
print(user_phone)
# Out:
# 01026452104

# %%
"""
Data Types : Integers
"""

#집에 있는 세가지 이상의 사물의 개수를 정수 변수로 표현하시오

Desks = 1
Tvs = 1
Sofas = 1
Computers = 1

# %%
"""
Data Types : Real Numbers
"""

#본인이 알고있는 세 개의 실수를 변수로 정의하시오
pi = 3.14
kospi_index = 3125.76
krw_usd_exchange = 1176.83

# %%
"""
Data Types : Strings
"""

#본인이 좋아하는 세 가지를 문자열로 정의하시오
favorite_game = "Lost Ark "
favorite_singer = "Winter "
favorite_color = "Gray "

favorites = favorite_game + favorite_singer + favorite_color
print(favorites)
# Out:
# Lost Ark Winter Gray

# %%
"""
x-Equals Operations
"""

a = 2
a +=2
print(a)
a -= 2
a **=3
print(a)
# Out:
# 4
# 8

# %%
"""
Errors
"""

print(my_name)
my_name = "Hyeon Woo"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-fc25b63d7d52> in <module>
#       3 """
#       4
# ----> 5 print(my_name)
#       6 my_name = "Hyeon Woo"
#
# NameError: name 'my_name' is not defined
