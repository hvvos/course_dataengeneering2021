# %%
"""
Booolean
"""

is_tested = False
print(type(is_tested))

a = 3
b = 3.14
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'int'>
# <class 'float'>

# %%
tested = True
passed = False

print("흥민이는 정처기 시험을 응시했는가?", tested)
print("흥민이는 정처기 시험을 통과했는가?", passed)

print(type(tested))
# Out:
# 흥민이는 정처기 시험을 응시했는가? True
# 흥민이는 정처기 시험을 통과했는가? False
# <class 'bool'>

# %%
a = 2
b = 3
a > b
# Out:
# False

# %%
print("Yes" == 'Yes')

print((2 > 1) == (5 < 10))

c = '2'
d = 2
print(c == d)
# Out:
# True
# True
# False

# %%
print("Yes" != "No")

val1 = 10
val2 = 20
print(val1 != val2)

print((10 > 1) != (10 > 1000))
# Out:
# True
# True
# True

# %%
"""
Conditional statements (if / elif / else)
"""

puppy = "maltese"
is_yes = False
age = 1

if puppy == "maltese":
    print("말티즈.")
    is_yes = True
    
    if age < 3:
        print("말티즈 새끼")
        
elif puppy == "poodle":
    print("푸들.")
    is_yes = True    
    
elif puppy == "shitzu":
    print("시츄.")
    is_yes = True
    
else:
    print("말티푸")
    is_yes = True
print(is_yes)
# Out:
# 말티즈.
# 말티즈 새끼
# True

# %%
"""
Exception Handling
"""

x = 1

try:
    print(y)
    print(x)

except:
    print('Error')
    
print('continue')
# Out:
# Error
# continue
