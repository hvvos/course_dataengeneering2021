# %%
months = ['쌍', '쇠', '복', '돌', '팽', '육', '쌍', '개', '칠', '갑', '삼', '방']

print(months)
# Out:
# ['쌍', '쇠', '복', '돌', '팽', '육', '쌍', '개', '칠', '갑', '삼', '방']

# %%
days = ['봉', '구', '욕', '포', '똥', '삼', '식', '석', '놈', '님', '년', '돌', '단', '득', '방', '질', '장', '걸', '래', '룡', '동', '순', '자', '박', '창', '언', '것', '포', '만', '단', '국']

print(days)
# Out:
# ['봉', '구', '욕', '포', '똥', '삼', '식', '석', '놈', '님', '년', '돌', '단', '득', '방', '질', '장', '걸', '래', '룡', '동', '순', '자', '박', '창', '언', '것', '포', '만', '단', '국']

# %%
def get_my_chosun_name(family_name, month, day):
    print("당신의 조선시대 이름은 %s 입니다." % (family_name + months[month-1] + days[day-1]))

get_my_chosun_name('박',4,3)
# Out:
# 당신의 조선시대 이름은 박돌욕 입니다.
